# %% [markdown]
# # Bronze → Silver Transformation
#
# Reads raw Parquet from the **Bronze** layer, converts all `date`/`Date` columns from
# datetime to `yyyy-MM-dd` string, and writes the result as **Delta** to the Silver layer.
#
# > **Requires:** Run `storagemount` first (or ensure OAuth2 Spark config is set on the cluster).

# %%
# %run ./autoload

# %%
dbutils.widgets.text("storage_account", "sadataeng260524dev", "Storage Account")
STORAGE_ACCOUNT = dbutils.widgets.get("storage_account")
auth  = bobydo.AdlsAuth(dbutils, spark)
paths = auth.setup(STORAGE_ACCOUNT)
BRONZE, SILVER, GOLD = paths["BRONZE"], paths["SILVER"], paths["GOLD"]

# %% [markdown]
# ## 1. Verify Bronze contents

# %%
df = spark.read.format('parquet').load(f"{BRONZE}/Sales/Customer.parquet")
display(df)

# %% [markdown]
# from pyspark.sql.functions import from_utc_timestamp, date_format
# from pyspark.sql.types import TimestampType
#
# df = df.withColumn(
#     "ModifiedDate",
#     date_format(from_utc_timestamp(df['ModifiedDate'].cast(TimestampType()), "UTC"), "yyyy-MM-dd")
# )
# display(df)

# %%
df = spark.read.format('parquet').load(f"{BRONZE}/Sales/Address.parquet")
display(df)

# %%
from pyspark.sql.functions import from_utc_timestamp, date_format
from pyspark.sql.types import TimestampType

df = df.withColumn(
    "ModifiedDate",
    date_format(from_utc_timestamp(df['ModifiedDate'].cast(TimestampType()), "UTC"), "yyyy-MM-dd")
)
display(df)

# %% [markdown]
# ## 3. Transform all Sales tables → Silver

# %%
from pyspark.sql.functions import from_utc_timestamp, date_format
from pyspark.sql.types import TimestampType

# Discover all tables from bronze
files = dbutils.fs.ls(f"{BRONZE}/Sales/")
table_names = sorted([
    f.name.replace(".parquet", "").replace("/", "")
    for f in files if f.name.endswith(".parquet")
])
print("Tables found:", table_names)

for table in table_names:
    input_path  = f"{BRONZE}/Sales/{table}.parquet"
    output_path = f"{SILVER}/Sales/{table}/"

    df = spark.read.format('parquet').load(input_path)

    # Convert any date/Date column from datetime → yyyy-MM-dd
    for col_name in df.columns:
        if "Date" in col_name or "date" in col_name:
            df = df.withColumn(
                col_name,
                date_format(from_utc_timestamp(df[col_name].cast(TimestampType()), "UTC"), "yyyy-MM-dd")
            )

    df.write.format('delta').mode('overwrite').save(output_path)
    print(f"  ✅ {table} → {output_path}")

print("\n✅ Bronze → Silver complete")

# %% [markdown]
# ## 4. Verify Silver output

# %%
display(dbutils.fs.ls(f"{SILVER}/Sales/"))

# %%
# Spot-check: preview last processed table
display(df)
